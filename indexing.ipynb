# %% [markdown]
# intro to indexing
# https://towardsdatascience.com/pandas-index-explained-b131beaf6f7b

# %%
import pandas as pd
import numpy as np

# %%
raw = pd.read_excel('A.xlsx')

# %%
adult  = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data",
                     names = ['age','workclass','fnlwgt', 'education', 'education_num','marital_status',
                              'occupation','relationship','race','sex','capital_gain',
                              'capital_loss', 'hours_per_week', 'native_country', 'label'], index_col = False)

print("Shape of data{}".format(adult.shape))
adult.head()
# Out:
# Shape of data(32561, 15)
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country   label
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  label           32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df = adult.sample(10000, random_state=100).sort_index(axis=0)
df.head()
# Out:
#     age   workclass  fnlwgt   education  education_num  \
# 3    53     Private  234721        11th              7
# 4    28     Private  338409   Bachelors             13
# 6    49     Private  160187         9th              5
# 8    31     Private   45781     Masters             14
# 11   30   State-gov  141297   Bachelors             13
#
#             marital_status          occupation    relationship  \
# 3       Married-civ-spouse   Handlers-cleaners         Husband
# 4       Married-civ-spouse      Prof-specialty            Wife
# 6    Married-spouse-absent       Other-service   Not-in-family
# 8            Never-married      Prof-specialty   Not-in-family
# 11      Married-civ-spouse      Prof-specialty         Husband
#
#                    race      sex  capital_gain  capital_loss  hours_per_week  \
# 3                 Black     Male             0             0              40
# 4                 Black   Female             0             0              40
# 6                 Black   Female             0             0              16
# 8                 White   Female         14084             0              50
# 11   Asian-Pac-Islander     Male             0             0              40
#
#     native_country   label
# 3    United-States   <=50K
# 4             Cuba   <=50K
# 6          Jamaica   <=50K
# 8    United-States    >50K
# 11           India    >50K

# %%
df.index
# Out:
# Int64Index([    3,     4,     6,     8,    11,    12,    16,    23,    26,
#                29,
#             ...
#             32525, 32526, 32529, 32536, 32541, 32542, 32543, 32548, 32550,
#             32556],
#            dtype='int64', length=10000)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'label'],
#       dtype='object')

# %%
df.iloc[2, 0]
# Out:
# 49

# %%
cols = ['age', 'education', 'marital_status', 'occupation', 'race', 'sex', 'native_country', 'label']

# %%
df = df[cols]

# %%
df.reset_index(inplace=True)

# %%
ind = df[df.native_country == ' India']

# %%
ind
# Out:
#       index  age      education          marital_status          occupation  \
# 4        11   30      Bachelors      Married-civ-spouse      Prof-specialty
# 312    1029   48        Masters   Married-spouse-absent               Sales
# 637    2130   28           11th               Separated        Adm-clerical
# 902    2989   44        Masters      Married-civ-spouse     Exec-managerial
# 1365   4480   30      Bachelors      Married-civ-spouse               Sales
# 1379   4523   57      Bachelors      Married-civ-spouse      Prof-specialty
# 1705   5629   46   Some-college      Married-civ-spouse        Craft-repair
# 2119   6964   29      Doctorate      Married-civ-spouse      Prof-specialty
# 2388   7844   35        Masters      Married-civ-spouse               Sales
# 2467   8124   36    Prof-school           Never-married      Prof-specialty
# 2796   9128   18        HS-grad           Never-married       Other-service
# 3016   9793   45        Masters      Married-civ-spouse        Adm-clerical
# 3063   9939   43    Prof-school      Married-civ-spouse      Prof-specialty
# 3265  10590   35    Prof-school           Never-married      Prof-specialty
# 3285  10661   59    Prof-school      Married-civ-spouse      Prof-specialty
# 3655  11835   38      Bachelors   Married-spouse-absent    Transport-moving
# 3811  12368   24   Some-college           Never-married        Adm-clerical
# 4171  13551   40      Doctorate      Married-civ-spouse     Exec-managerial
# 4515  14685   36        Masters                 Widowed        Tech-support
# 5192  16923   41      Assoc-voc      Married-civ-spouse       Other-service
# 5471  17834   29        HS-grad   Married-spouse-absent    Transport-moving
# 6122  19926   27    Prof-school           Never-married      Prof-specialty
# 6133  19959   45            9th      Married-civ-spouse   Handlers-cleaners
# 6482  21128   30        Masters      Married-civ-spouse      Prof-specialty
# 7391  24154   46      Bachelors      Married-civ-spouse               Sales
# 7891  25739   35        Masters      Married-civ-spouse      Prof-specialty
# 8069  26356   34        Masters      Married-civ-spouse     Exec-managerial
# 8355  27244   33        Masters      Married-civ-spouse      Prof-specialty
# 8551  27889   17           11th           Never-married               Sales
# 8580  27974   33      Bachelors      Married-civ-spouse        Adm-clerical
# 8687  28264   51    Prof-school      Married-civ-spouse      Prof-specialty
# 8742  28433   42        Masters      Married-civ-spouse      Prof-specialty
# 8751  28452   53        Masters      Married-civ-spouse      Prof-specialty
# 8820  28693   32           11th           Never-married        Craft-repair
# 8853  28798   30        Masters                Divorced      Prof-specialty
# 9513  30871   26        Masters           Never-married      Prof-specialty
# 9644  31327   38      Bachelors      Married-civ-spouse      Prof-specialty
#
#                      race      sex native_country   label
# 4      Asian-Pac-Islander     Male          India    >50K
# 312    Asian-Pac-Islander     Male          India   <=50K
# 637    Asian-Pac-Islander   Female          India   <=50K
# 902    Asian-Pac-Islander     Male          India   <=50K
# 1365   Asian-Pac-Islander     Male          India   <=50K
# 1379   Asian-Pac-Islander     Male          India   <=50K
# 1705   Asian-Pac-Islander     Male          India   <=50K
# 2119   Asian-Pac-Islander     Male          India   <=50K
# 2388                White     Male          India   <=50K
# 2467                Other     Male          India    >50K
# 2796   Asian-Pac-Islander   Female          India   <=50K
# 3016                White     Male          India   <=50K
# 3063   Asian-Pac-Islander     Male          India    >50K
# 3265   Asian-Pac-Islander     Male          India    >50K
# 3285   Asian-Pac-Islander     Male          India    >50K
# 3655                Other     Male          India   <=50K
# 3811                White     Male          India   <=50K
# 4171   Asian-Pac-Islander     Male          India    >50K
# 4515   Asian-Pac-Islander   Female          India   <=50K
# 5192   Asian-Pac-Islander     Male          India    >50K
# 5471   Asian-Pac-Islander     Male          India    >50K
# 6122   Asian-Pac-Islander     Male          India   <=50K
# 6133   Asian-Pac-Islander     Male          India   <=50K
# 6482   Asian-Pac-Islander     Male          India    >50K
# 7391                White     Male          India    >50K
# 7891   Asian-Pac-Islander     Male          India    >50K
# 8069   Asian-Pac-Islander     Male          India    >50K
# 8355   Asian-Pac-Islander     Male          India   <=50K
# 8551                White   Female          India   <=50K
# 8580   Asian-Pac-Islander     Male          India   <=50K
# 8687                Other     Male          India    >50K
# 8742   Asian-Pac-Islander     Male          India    >50K
# 8751   Asian-Pac-Islander     Male          India    >50K
# 8820   Asian-Pac-Islander     Male          India   <=50K
# 8853   Asian-Pac-Islander     Male          India    >50K
# 9513   Asian-Pac-Islander     Male          India   <=50K
# 9644   Asian-Pac-Islander     Male          India    >50K

# %%
cross = pd.crosstab(ind.sex, ind.label)
cross
# Out:
# label     <=50K   >50K
# sex
#  Female       4      0
#  Male        16     17

# %%
cross.index
# Out:
# Index([' Female', ' Male'], dtype='object', name='sex')

# %%
cross.loc[' Male']
# Out:
# label
#  <=50K    16
#  >50K     17
# Name:  Male, dtype: int64

# %%
ind_50 = ind[ind['label'] == ' >50K']
ind_50.head()
# Out:
#       index  age     education       marital_status       occupation  \
# 4        11   30     Bachelors   Married-civ-spouse   Prof-specialty
# 2467   8124   36   Prof-school        Never-married   Prof-specialty
# 3063   9939   43   Prof-school   Married-civ-spouse   Prof-specialty
# 3265  10590   35   Prof-school        Never-married   Prof-specialty
# 3285  10661   59   Prof-school   Married-civ-spouse   Prof-specialty
#
#                      race    sex native_country  label
# 4      Asian-Pac-Islander   Male          India   >50K
# 2467                Other   Male          India   >50K
# 3063   Asian-Pac-Islander   Male          India   >50K
# 3265   Asian-Pac-Islander   Male          India   >50K
# 3285   Asian-Pac-Islander   Male          India   >50K

# %%
adult['hours_per_week'][ind_50.index]
# Out:
# 4       40
# 2467    40
# 3063    40
# 3265    60
# 3285    20
# 4171    49
# 5192    45
# 5471    35
# 6482    55
# 7391    37
# 7891    40
# 8069    84
# 8687    20
# 8742    60
# 8751    65
# 8853    12
# 9644    25
# Name: hours_per_week, dtype: int64

# %%
adult['hours_per_week'][ind_50.index].mean()
# Out:
# 42.76470588235294

# %%
ind_05 = ind[~ind.index.isin(ind_50.index)]
ind_05
# Out:
#       index  age      education          marital_status          occupation  \
# 312    1029   48        Masters   Married-spouse-absent               Sales
# 637    2130   28           11th               Separated        Adm-clerical
# 902    2989   44        Masters      Married-civ-spouse     Exec-managerial
# 1365   4480   30      Bachelors      Married-civ-spouse               Sales
# 1379   4523   57      Bachelors      Married-civ-spouse      Prof-specialty
# 1705   5629   46   Some-college      Married-civ-spouse        Craft-repair
# 2119   6964   29      Doctorate      Married-civ-spouse      Prof-specialty
# 2388   7844   35        Masters      Married-civ-spouse               Sales
# 2796   9128   18        HS-grad           Never-married       Other-service
# 3016   9793   45        Masters      Married-civ-spouse        Adm-clerical
# 3655  11835   38      Bachelors   Married-spouse-absent    Transport-moving
# 3811  12368   24   Some-college           Never-married        Adm-clerical
# 4515  14685   36        Masters                 Widowed        Tech-support
# 6122  19926   27    Prof-school           Never-married      Prof-specialty
# 6133  19959   45            9th      Married-civ-spouse   Handlers-cleaners
# 8355  27244   33        Masters      Married-civ-spouse      Prof-specialty
# 8551  27889   17           11th           Never-married               Sales
# 8580  27974   33      Bachelors      Married-civ-spouse        Adm-clerical
# 8820  28693   32           11th           Never-married        Craft-repair
# 9513  30871   26        Masters           Never-married      Prof-specialty
#
#                      race      sex native_country   label
# 312    Asian-Pac-Islander     Male          India   <=50K
# 637    Asian-Pac-Islander   Female          India   <=50K
# 902    Asian-Pac-Islander     Male          India   <=50K
# 1365   Asian-Pac-Islander     Male          India   <=50K
# 1379   Asian-Pac-Islander     Male          India   <=50K
# 1705   Asian-Pac-Islander     Male          India   <=50K
# 2119   Asian-Pac-Islander     Male          India   <=50K
# 2388                White     Male          India   <=50K
# 2796   Asian-Pac-Islander   Female          India   <=50K
# 3016                White     Male          India   <=50K
# 3655                Other     Male          India   <=50K
# 3811                White     Male          India   <=50K
# 4515   Asian-Pac-Islander   Female          India   <=50K
# 6122   Asian-Pac-Islander     Male          India   <=50K
# 6133   Asian-Pac-Islander     Male          India   <=50K
# 8355   Asian-Pac-Islander     Male          India   <=50K
# 8551                White   Female          India   <=50K
# 8580   Asian-Pac-Islander     Male          India   <=50K
# 8820   Asian-Pac-Islander     Male          India   <=50K
# 9513   Asian-Pac-Islander     Male          India   <=50K

# %%
adult['hours_per_week'][ind_05.index].mean()
# Out:
# 47.0

# %%
A = pd.read_excel('A.xlsx')

# %%
A
# Out:
#   col0 col1 col2 col3 col4
# 0   AA   BA   CA   DA   EA
# 1   AB   BB   CB   DB   EB
# 2   AC   BC   CC   DC   EC
# 3   AD   BD   CD   DD   ED
# 4   AE   BE   CE   DE   EE

# %%
B = pd.read_excel('B.xlsx')

# %%
B
# Out:
#    C0  C1  C2  C3  C4  C5  C6
# 0  0A  1A  2A  3A  4A  5A  6A
# 1  0B  1B  2B  3B  4B  5B  6B
# 2  0C  1C  2C  3C  4C  5C  6C
# 3  0D  1D  2D  3D  4D  5D  6D
# 4  0E  1E  2E  3E  4E  5E  6E

# %%
B.columns
# Out:
# Index(['C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6'], dtype='object')

# %%
C = pd.read_excel('C.xlsx')

# %%
C.info
# Out:
# <bound method DataFrame.info of    c1  c2  c3  c4  c5
# 0  10  20  30  40  50
# 1  11  21  31  41  51
# 2  12  22  32  42  52
# 3  13  23  33  43  53
# 4  14  24  34  44  54
# 5  15  25  35  45  55
# 6  16  26  36  46  56
# 7  17  27  37  47  57
# 8  18  28  38  48  58
# 9  19  29  39  49  59>

# %%
c = C.iloc[1::2].drop(columns = {'c3'})

# %%
c.reset_index(inplace=True)

# %%
c
# Out:
#    index  c1  c2  c4  c5
# 0      1  11  21  41  51
# 1      3  13  23  43  53
# 2      5  15  25  45  55
# 3      7  17  27  47  57
# 4      9  19  29  49  59

# %%
ind = c.iloc[::2]

# %%
ind
# Out:
#    index  c1  c2  c4  c5
# 0      1  11  21  41  51
# 2      5  15  25  45  55
# 4      9  19  29  49  59

# %%
cross = pd.crosstab(ind.c2, ind.c5)
cross
# Out:
# c5  51  55  59
# c2
# 21   1   0   0
# 25   0   1   0
# 29   0   0   1

# %%
cross.index
# Out:
# Int64Index([21, 25, 29], dtype='int64', name='c2')

# %%
cross.loc[25]
# Out:
# c5
# 51    0
# 55    1
# 59    0
# Name: 25, dtype: int64

# %%
ind_51 = ind[ind['c5'] > 51]

# %%
ind_51
# Out:
#    index  c1  c2  c4  c5
# 2      5  15  25  45  55
# 4      9  19  29  49  59

# %%
ind_51['c3'] = C['c3'][ind_51.index]
# Out:
# /Users/ptr/Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ind_51
# Out:
#    index  c1  c2  c4  c5  c3
# 2      5  15  25  45  55  32
# 4      9  19  29  49  59  34

# %%
ind
# Out:
#    index  c1  c2  c4  c5
# 0      1  11  21  41  51
# 2      5  15  25  45  55
# 4      9  19  29  49  59

# %%
ind_15 = ind[~ind.index.isin(ind_51.index)]
ind_
